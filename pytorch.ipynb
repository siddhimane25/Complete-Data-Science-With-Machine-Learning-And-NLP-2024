# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhimane25/Complete-Data-Science-With-Machine-Learning-And-NLP-2024/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x= torch.tensor([1,2,3,4,5])
print(x)
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
y= torch.tensor([
    [1,2],
    [3,4]]
)
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
z = torch.zeros(3,2)
print(z)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
o = torch.ones(2,2)
print(o)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
r = torch.rand(2,2)
print(r)
# Out:
# tensor([[0.8278, 0.8882],
#         [0.6231, 0.3696]])

# %%
a = torch.tensor([
    [1,2,3],
    [4,5,6]]
)
print(a.shape)
# Out:
# torch.Size([2, 3])

# %%
i = torch.tensor([10, 20, 30])
print(i[0])
print(i[1])
# Out:
# tensor(10)
# tensor(20)

# %%
d_2 = torch.tensor([
    [10,20,30],
    [40,50,60]
])
print(d_2[0, 1])
print(d_2[1,2])
# Out:
# tensor(20)
# tensor(60)

# %%
a = torch.tensor([1,2,3])
b = torch.tensor([4,5,6])
print(a + b)
print(a * b)
# Out:
# tensor([5, 7, 9])
# tensor([ 4, 10, 18])
